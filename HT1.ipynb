# %% [markdown]
# # Hoja de trabajo No.1: Análisis Exploratorio

# %% [markdown]
# ## Importar librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importar datos

# %%
datos = pd.read_csv('moviesMD.csv')

# %% [markdown]
# ## Lectura de datos

# %%
datos.head()
# Out:
#    id    budget                            genres  \
# 0   5   4000000                      Crime|Comedy
# 1   6  21000000             Action|Thriller|Crime
# 2  11  11000000  Adventure|Action|Science Fiction
# 3  12  94000000                  Animation|Family
# 4  13  55000000              Comedy|Drama|Romance
#
#                                             homePage  \
# 0          https://www.miramax.com/movie/four-rooms/
# 1                                                NaN
# 2  http://www.starwars.com/films/star-wars-episod...
# 3              http://movies.disney.com/finding-nemo
# 4                                                NaN
#
#                             productionCompany productionCompanyCountry  \
# 0                        Miramax|A Band Apart                    US|US
# 1  Universal Pictures|Largo Entertainment|JVC                 US|US|JP
# 2                  Lucasfilm|20th Century Fox                    US|US
# ...

# %% [markdown]
# ## Resumen estadístico

# %%
datos.describe()
# Out:
#             revenue       runtime    popularity      voteAvg     voteCount  \
# count  1.000100e+04  10001.000000   9999.000000  9999.000000   9999.000000
# mean   5.673225e+07    100.258574     51.397715     6.483468   1342.481748
# std    1.495790e+08     27.792771    216.740056     0.984321   2564.305389
# min    0.000000e+00      0.000000      4.258000     1.300000      1.000000
# 25%    0.000000e+00     90.000000     14.578500     5.900000    120.000000
# 50%    1.630800e+05    100.000000     21.909000     6.500000    415.000000
# 75%    4.479322e+07    113.000000     40.656000     7.200000   1316.000000
# max    2.847246e+09    750.000000  11474.647000    10.000000  30788.000000
#
#        genresAmount  productionCoAmount  productionCountriesAmount  \
# count   9999.000000         9999.000000                9999.000000
# mean       2.596260            3.171617                   1.751075
# std        1.154373            2.539772                   3.012235
# ...

# %% [markdown]
# ## Tipos de datos

# %%
datos.dtypes
# Out:
# id                            object
# budget                        object
# genres                        object
# homePage                      object
# productionCompany             object
# productionCompanyCountry      object
# productionCountry             object
# revenue                        int64
# runtime                        int64
# video                         object
# director                      object
# actors                        object
# actorsPopularity              object
# actorsCharacter               object
# originalTitle                 object
# title                         object
# originalLanguage              object
# popularity                   float64
# releaseDate                   object
# voteAvg                      float64
# voteCount                    float64
# genresAmount                 float64
# productionCoAmount           float64
# productionCountriesAmount    float64
# actorsAmount                 float64
# ...

# %% [markdown]
# ## Info

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         10001 non-null  object
#  1   budget                     10001 non-null  object
#  2   genres                     9948 non-null   object
#  3   homePage                   4194 non-null   object
#  4   productionCompany          9544 non-null   object
#  5   productionCompanyCountry   8721 non-null   object
#  6   productionCountry          9768 non-null   object
#  7   revenue                    10001 non-null  int64
#  8   runtime                    10001 non-null  int64
#  9   video                      9515 non-null   object
#  10  director                   9927 non-null   object
#  11  actors                     9921 non-null   object
#  12  actorsPopularity           9914 non-null   object
# ...

# %% [markdown]
# ## Visualizacion gráfica

# %%
# Convertir la columna 'budget' a numérica si es necesario
datos['budget'] = pd.to_numeric(datos['budget'], errors='coerce')

# Visualizar la distribución de algunas variables importantes
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
datos['popularity'].plot(kind='hist', bins=20, title='Distribución de popularidad')

plt.subplot(2, 2, 2)
datos['budget'].plot(kind='hist', bins=20, title='Distribución de presupuesto')

plt.subplot(2, 2, 3)
datos['revenue'].plot(kind='hist', bins=20, title='Distribución de ingresos')

plt.subplot(2, 2, 4)
datos['runtime'].plot(kind='hist', bins=20, title='Distribución de duración')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Preguntas

# %%
#Películas con mayor presupuesto
presupuesto = datos.sort_values(by='budget', ascending=False).head(10)
presupuesto = presupuesto[['id', 'title', 'budget']]
print(presupuesto)
# Out:
#           id                                        title       budget
# 716     1865  Pirates of the Caribbean: On Stranger Tides  380000000.0
# 4711   99861                      Avengers: Age of Ultron  365000000.0
# 5953  299534                            Avengers: Endgame  356000000.0
# 4954  141052                               Justice League  300000000.0
# 5954  299536                       Avengers: Infinity War  300000000.0
# 163      285     Pirates of the Caribbean: At World's End  300000000.0
# 607     1452                             Superman Returns  270000000.0
# 7135  420818                                The Lion King  260000000.0
# 3792   38757                                      Tangled  260000000.0
# 280      559                                 Spider-Man 3  258000000.0

# %%
#Peliculas con mas ingresos
ingresos = datos.sort_values(by='revenue', ascending=False).head(10)
ingresos = ingresos[['id', 'title', 'revenue']]
print(ingresos)
# Out:
#           id                         title     revenue
# 3211   19995                        Avatar  2847246203
# 5953  299534             Avengers: Endgame  2797800564
# 307      597                       Titanic  2187463944
# 4948  140607  Star Wars: The Force Awakens  2068223624
# 5954  299536        Avengers: Infinity War  2046239637
# 4915  135397                Jurassic World  1671713208
# 7135  420818                 The Lion King  1667635327
# 9050  634649       Spider-Man: No Way Home  1631853496
# 3398   24428                  The Avengers  1518815515
# 5088  168259                     Furious 7  1515047671

# %%
#Pelicula con mas votos
masVotos = datos.sort_values(by='voteCount', ascending=False).head(1)
masVotos = masVotos[['id', 'title', 'voteCount']]
print(masVotos)
# Out:
#          id      title  voteCount
# 3512  27205  Inception    30788.0

# %%
#Pelicula con menos votos
menosVotos = datos.sort_values(by='voteCount', ascending=True).head(1)
menosVotos = menosVotos[['id', 'title', 'voteCount']]
print(menosVotos)
# Out:
#           id                                           title  voteCount
# 9247  672588  Steven Universe: The Movie: Behind the Curtain        1.0

# %%
#Grafico de barras de la cantidad de peliculas por año
datos['releaseDate'] = pd.to_datetime(datos['releaseDate'])
peliculasDate = datos.groupby(datos['releaseDate'].dt.year)['releaseDate'].count()
plt.figure(figsize=(20, 6))
peliculasDate.plot(kind='bar', color='skyblue')
plt.title('Cantidad de Películas por Año de Estreno')
plt.xlabel('Año de Estreno')
plt.ylabel('Cantidad de Películas')
plt.show()

# %%
#Año con mas peliculas
datos['releaseDate'] = pd.to_datetime(datos['releaseDate'])
datePeliculas = datos['releaseDate'].dt.year.value_counts().reset_index()
datePeliculas.columns = ['year', 'count']
masPeliculas = datePeliculas.iloc[0]
print(masPeliculas)
# Out:
# year     2021.0
# count     816.0
# Name: 0, dtype: float64

# %%
#Genero principal de peliculas
datos['releaseDate'] = pd.to_datetime(datos['releaseDate'])
peliculasRecientes = datos.sort_values(by='releaseDate', ascending=False).head(20)
peliculasRecientes['genres'] = peliculasRecientes['genres'].str.split(',')
generoPeliculas = peliculasRecientes['genres'].apply(lambda x: x[0] if isinstance(x, list) and x else None)
print(generoPeliculas)
# Out:
# 9517                                 Drama
# 9546                          Comedy|Drama
# 9198                         Drama|Mystery
# 9809                              Thriller
# 9587           Action|Thriller|Crime|Drama
# 9983                           Documentary
# 9952                          Action|Drama
# 9258                                  None
# 9242                                  None
# 9867                               Romance
# 9684    Animation|Adventure|Fantasy|Family
# 9878               Horror|Thriller|Mystery
# 9989                                Comedy
# 9347                Comedy|Romance|Fantasy
# 9254                                 Drama
# 9997                                Comedy
# 9480                         Comedy|Horror
# 9561                         Drama|Fantasy
# 9171               Action|Adventure|Comedy
# 9873                        Comedy|Romance
# Name: genres, dtype: object

# %%
#Grafico de generos mas predominantes
datos['genres'] = datos['genres'].apply(lambda x: 'Unknown' if pd.isnull(x) else x)
datos['generos'] = datos['genres'].str.split(',').apply(lambda x: [genre.strip() for genre in x] if isinstance(x, list) else [])
generos = datos['generos'].explode()
frecuenciaGeneros = generos.value_counts()
top_generos = frecuenciaGeneros.head(10)

top_generos.plot(kind='bar', color='skyblue')
plt.title('Géneros Más Predominantes')
plt.xlabel('Género')
plt.ylabel('Frecuencia')
plt.show()

# %%
#Grafico de generos con mayores ganancias
datos['genres'] = datos['genres'].apply(lambda x: 'Unknown' if pd.isnull(x) else x)
datos['revenue'] = pd.to_numeric(datos['revenue'], errors='coerce')
datos['generos'] = datos['genres'].str.split(',').apply(lambda x: [genre.strip() for genre in x] if isinstance(x, list) else [])
generos = datos['generos'].explode()
ganacias = pd.DataFrame({'Genero': generos, 'Ganancias': datos['revenue']})
ganaciasGenero = ganacias.groupby('Genero')['Ganancias'].sum()
topGeneros = ganaciasGenero.nlargest(10)

topGeneros.plot(kind='bar', color='skyblue')
plt.title('Top 10 Géneros con Mayores Ganancias')
plt.xlabel('Género')
plt.ylabel('Ganancias Totales')
plt.show()

# %%
#Grafico de relacion entre la cantidad de actores y los ingresos
datos['actors'] = datos['actors'].apply(lambda x: 'Unknown' if pd.isnull(x) else x)
datos['num_actors'] = datos['actors'].apply(lambda x: len(x.split(',')) if pd.notnull(x) else 0)
datos['revenue'] = pd.to_numeric(datos['revenue'], errors='coerce')
plt.figure(figsize=(12, 6))
plt.scatter(datos['num_actors'], datos['revenue'], alpha=0.5)
plt.title('Relación entre la Cantidad de Actores y los Ingresos')
plt.xlabel('Cantidad de Actores')
plt.ylabel('Ingresos')
plt.show()

# %%
#Cantidad promedio de actores en peliculas recientes
año_actual = pd.to_datetime('now').year
peliculas_recientes = datos[datos['releaseDate'].dt.year >= (año_actual - 5)]
promedio_actores_recientes = peliculas_recientes['num_actors'].mean()
print(f"Cantidad promedio de actores en películas recientes: {promedio_actores_recientes:.2f}")
# Out:
# Cantidad promedio de actores en películas recientes: 1.00
# C:\Users\50242\AppData\Local\Temp\ipykernel_21608\3192004625.py:2: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   año_actual = pd.to_datetime('now').year

# %%
#Grafico de cantidad de hombres y mujeres en el reparto y la popularidad
datos['actors'] = datos['actors'].apply(lambda x: 'Unknown' if pd.isnull(x) else x)
datos['num_male_actors'] = datos['actors'].apply(lambda x: x.lower().count('male') if pd.notnull(x) else 0)
datos['num_female_actors'] = datos['actors'].apply(lambda x: x.lower().count('female') if pd.notnull(x) else 0)
plt.figure(figsize=(12, 6))
plt.scatter(datos['num_male_actors'], datos['popularity'], label='Hombres', alpha=0.5)
plt.scatter(datos['num_female_actors'], datos['popularity'], label='Mujeres', alpha=0.5)
plt.title('Relación entre la Cantidad de Hombres/Mujeres en el Reparto y la Popularidad')
plt.xlabel('Cantidad de Actores')
plt.ylabel('Popularidad')
plt.legend()
plt.show()

# %%
#Grafico de cantidad de hombres y mujeres en el reparto y los ingresos
datos['revenue'] = pd.to_numeric(datos['revenue'], errors='coerce')
plt.figure(figsize=(12, 6))
plt.scatter(datos['num_male_actors'], datos['revenue'], label='Hombres', alpha=0.5)
plt.scatter(datos['num_female_actors'], datos['revenue'], label='Mujeres', alpha=0.5)
plt.title('Relación entre la Cantidad de Hombres/Mujeres en el Reparto y los Ingresos')
plt.xlabel('Cantidad de Actores')
plt.ylabel('Ingresos')
plt.legend()
plt.show()

# %%
#Directores de las peliculas mejor calificadas
directores = datos.sort_values(by='voteCount', ascending=False).head(20)
directores = directores[['id', 'title', 'voteCount', 'director']]
print(directores)
# Out:
#           id                                              title  voteCount  \
# 3512   27205                                          Inception    30788.0
# 5028  157336                                       Interstellar    27644.0
# 87       155                                    The Dark Knight    26690.0
# 3398   24428                                       The Avengers    26215.0
# 5890  293660                                           Deadpool    26178.0
# 3211   19995                                             Avatar    24766.0
# 4826  118340                            Guardians of the Galaxy    23806.0
# 5954  299536                             Avengers: Infinity War    23715.0
# 275      550                                         Fight Club    23338.0
# 374      680                                       Pulp Fiction    22501.0
# 695     1726                                           Iron Man    22099.0
# ...

# %%
# Filtrar las columnas relevantes
data = datos[['budget', 'revenue']]

# Eliminar filas con valores no numéricos en 'budget'
data = data[data['budget'].apply(pd.to_numeric, errors='coerce').notna()]

# Eliminar filas con valores nulos en 'revenue'
data = data.dropna(subset=['revenue'])

# Calcular la correlación entre presupuestos y ingresos
correlation = data['budget'].corr(data['revenue'])

# Crear un diagrama de dispersión
plt.scatter(data['budget'], data['revenue'])
plt.title('Diagrama de Dispersión: Presupuestos vs. Ingresos')
plt.xlabel('Presupuesto')
plt.ylabel('Ingresos')
plt.show()

# Crear un histograma para presupuestos
plt.hist(data['budget'], bins=30, color='blue', alpha=0.7)
plt.title('Histograma de Presupuestos')
plt.xlabel('Presupuesto')
plt.ylabel('Frecuencia')
plt.show()

# Crear un histograma para ingresos
plt.hist(data['revenue'], bins=30, color='green', alpha=0.7)
plt.title('Histograma de Ingresos')
plt.xlabel('Ingresos')
plt.ylabel('Frecuencia')
plt.show()

print(f"Correlación entre presupuestos y ingresos: {correlation}")
# Out:
# Correlación entre presupuestos y ingresos: 0.7574540424955986

# %%
# Extraer el mes de la columna 'releaseDate'
datos['releaseMonth'] = pd.to_datetime(datos['releaseDate']).dt.month

# Agrupar por mes y calcular los ingresos promedio
monthly_avg_revenue = datos.groupby('releaseMonth')['revenue'].mean()

# Ordenar los resultados por mes
monthly_avg_revenue = monthly_avg_revenue.sort_index()

# Crear un gráfico de barras para visualizar los ingresos promedio por mes
plt.bar(monthly_avg_revenue.index, monthly_avg_revenue)
plt.title('Ingresos Promedio por Mes de Lanzamiento')
plt.xlabel('Mes de Lanzamiento')
plt.ylabel('Ingresos Promedio')
plt.xticks(range(1, 13), ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic'])
plt.show()

# %%
# Extraer el mes de la columna 'releaseDate'
datos['releaseMonth'] = pd.to_datetime(datos['releaseDate']).dt.month

# Agrupar por mes y calcular los ingresos totales
monthly_total_revenue = datos.groupby('releaseMonth')['revenue'].sum()

# Identificar los meses con mejores ingresos
best_months = monthly_total_revenue.idxmax()
best_months_revenue = monthly_total_revenue.max()

print(f"Meses con mejores ingresos: {best_months} con ingresos totales de {best_months_revenue}")

# Calcular el promedio de lanzamientos por mes
average_movies_per_month = datos.groupby('releaseMonth').size().mean()

print(f"Promedio de películas lanzadas por mes: {average_movies_per_month}")

# Crear un gráfico de barras para visualizar los ingresos totales por mes
plt.bar(monthly_total_revenue.index, monthly_total_revenue)
plt.title('Ingresos Totales por Mes de Lanzamiento')
plt.xlabel('Mes de Lanzamiento')
plt.ylabel('Ingresos Totales')
plt.xticks(range(1, 13), ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic'])
plt.show()
# Out:
# Meses con mejores ingresos: 6.0 con ingresos totales de 77597881637
# Promedio de películas lanzadas por mes: 833.25

# %%
# Seleccionar las columnas relevantes
data = datos[['voteAvg', 'revenue']]

# Eliminar filas con valores nulos
data = data.dropna()

# Calcular la correlación entre las calificaciones y los ingresos
correlation = data['voteAvg'].corr(data['revenue'])

# Crear un diagrama de dispersión
plt.scatter(data['voteAvg'], data['revenue'])
plt.title('Diagrama de Dispersión: Calificaciones vs. Ingresos')
plt.xlabel('Calificaciones')
plt.ylabel('Ingresos')
plt.show()

print(f"Correlación entre calificaciones y ingresos: {correlation}")
# Out:
# Correlación entre calificaciones y ingresos: 0.14126438971337796

# %%
# Agrupar por género y calcular la duración promedio
genre_groups = datos.groupby('genres')['runtime'].mean().reset_index()

# Ordenar de mayor a menor
genre_groups = genre_groups.sort_values('runtime', ascending=False)

# Imprimir el género con mayor duración promedio
print("El género con las películas más largas es:", genre_groups.iloc[0]['genres'])

# Obtener los primeros 10 géneros ordenados por duración
top_genres = genre_groups.head(10)

# Gráfico con solo top 10 géneros 

plt.bar(top_genres['genres'], top_genres['runtime']) 

plt.xlabel('Género')
plt.ylabel('Duración Promedio')
plt.title('Top 10 Géneros por Duración Promedio')

# Rotar las etiquetas del eje x
plt.xticks(rotation=45) 

plt.tight_layout()
plt.show()
# Out:
# El género con las películas más largas es: War|History|Adventure|Drama
